# %%
import logging
from collections import deque
import math
import pandas as pd
import numpy as np 
import os
from queue import Queue

# %%
import logging
from collections import deque
import math
 
class Trans:
    datetime=None
    amount=None
    price=None
 
    def __init__(self, datetime, amount, price):
        self.datetime=datetime
        self.amount=amount
        self.price=price
     
    def getInfo(self):
        return(str(self.datetime)+"; "+
                str(self.amount)+"; "+
                str(self.price))
 
def balanceFifo(all_trans):
    trx = []
    qTransactions = deque() 
 
    for t in all_trans:
        #Add first element to the queue
        if len(qTransactions)==0:
            logging.debug('Added the first element: %s',t.getInfo())
            qTransactions.append(t)
            continue
 
        while (t.amount!=0 and len(qTransactions)>0):
            #investigate the first element from the queue
            tq=qTransactions.popleft()
            #the same type of transaction: both sell or both buy
            if tq.amount*t.amount>0:
                #return the first element back to the same place
                qTransactions.appendleft(tq)
                #add the new element to the list
                qTransactions.append(t)
                logging.debug('Added: %s',t.getInfo())
                break
             
            #contrary transactions: (sell and buy) or (buy and sell) 
            if tq.amount*t.amount<0:
                logging.debug('Transaction : %s',t.getInfo())
                logging.debug('... try to balance with: %s',tq.getInfo())
 
                #The element in the queue have more units and takes in the current transaction
                if abs(tq.amount)>abs(t.amount):
                    trx.append(insertTransaction(tq.datetime,t.datetime,\
                            math.copysign(t.amount,tq.amount), tq.price,t.price))
                    

                    #update the amount of the element in the queue
                    tq.amount=tq.amount+t.amount
                    #return the element back to the same place
                    qTransactions.appendleft(tq)
                    logging.debug('Removed transaction: %s',t.getInfo())
                    #the transaction has been balanced, take a new transaction
                    break
                 
                #The element from the queue and transaction have the same amount of units
                if abs(tq.amount)==abs(t.amount):
                    trx.append(insertTransaction(tq.datetime,t.datetime,\
                            math.copysign(t.amount,tq.amount), tq.price,t.price))

                     
                    #update the amount in the transaction 
                    t.amount=0
                    logging.debug('Balanced, removed transaction: %s',t.getInfo())
                    logging.debug('Balanced, removed from the queue: %s',tq.getInfo())
                    #the transaction has been balanced, take a new transaction
                    continue
                #The transaction has more units
                if abs(tq.amount)<abs(t.amount):
                    #update the units in transaction, (remove element from the queue)
                    t.amount=t.amount+tq.amount
                    
                    trx.append(insertTransaction(tq.datetime,t.datetime,tq.amount,tq.price,t.price))
                    logging.debug('Removed from queue: %s',tq.getInfo())
                    

                    #the transaction has not been balanced, 
                    #take a new element from the queue (t.amount>0)
                    continue
        
                 
        #We have unbalanced transaction but the queue is empty            
        if (t.amount!=0 and len(qTransactions)==0):
            #Add unbalanced transaction to the queue
            #The queue changes polarisation
            qTransactions.append(t)
            print('Left element: %s',t.getInfo())
     
    #If something remained in the queue, treat it as open or part-open transactions
    while (len(qTransactions)>0):
        tq=qTransactions.popleft()
        print('Remained on list transaction:',tq.getInfo())
 
    return trx
def insertTransaction(dateStart,dateEnd,amount,priceStart,priceEnd):
    
    return {"Buy Date":dateStart,"Buy Price": priceStart,"Sell Date": dateEnd,"Sell Price": priceEnd,"Quantity":amount, "Gain": amount*(priceEnd-priceStart)}

# %%
import pandas as pd 
df = pd.read_excel('test2.xlsx').fillna("")

# %%
trans_list=list()

for i in df.index:
    
    rows = df.iloc[i]
    
    target = rows[['Date','Shares','Price']].tolist()
    if rows['TransactionType'] == 'Sale' or rows['TransactionType'].upper() == 'S':
        trans = Trans(target[0].strftime("%Y-%m-%d"),target[1]*-1,target[2])
        trans.getInfo()
    else:
        trans = Trans(target[0].strftime("%Y-%m-%d"),target[1],target[2])
        trans.getInfo()

    trans_list.append(trans)
    
fifo = balanceFifo(trans_list)
trans_list.clear()
# Out:
# Remained on list transaction: 2020-01-03; 50; 5
# Remained on list transaction: 2020-01-03; 100; 5

# %%
end = pd.DataFrame(fifo)

# %%
end
# Out:
#      Buy Date  Buy Price   Sell Date  Sell Price  Quantity   Gain
# 0  2020-01-03          5  2020-01-04          15      50.0  500.0

# %%
indx = np.argsort(end['Gain'])[:3]

# %%
end.loc[indx,:]
# Out:
#          Buy Date  Buy Price   Sell Date  Sell Price  Quantity         Gain
# 26919  2018-02-22  54.041975  2018-03-01   43.467961     324.0 -3425.980536
# 26898  2018-02-22  54.116667  2018-03-01   43.467961     300.0 -3194.611800
# 26928  2018-02-22  54.150000  2018-03-01   43.753800     295.0 -3066.879000

# %%
df = pd.read_clipboard()

# %%
import pandas as pd

# %%
# Out:
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 2587)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1530)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 108)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 118)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 33)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 2590)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 485)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 435)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 221)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 464)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 461)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 371)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 4636)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 6665)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 385)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 6662)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 226)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 326)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 22)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 459)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 439)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 187)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1522)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1541)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 6657)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 111)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 412)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 167)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 511)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 57)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1556)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 391)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 411)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 386)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 149)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3621)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 49)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 487)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 516)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 230)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1587)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3604)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 241)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 46)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 113)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 237)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 2593)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 7668)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 4635)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 420)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 2592)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 430)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 349)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 234)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 389)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3607)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 7667)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 367)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 128)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 449)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 34)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 132)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 16)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 193)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 496)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1581)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 489)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 277)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 381)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 493)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 168)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 24)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 490)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 517)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 377)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 473)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3606)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1585)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 472)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1551)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1545)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3620)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 122)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 406)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 203)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 470)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 519)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 153)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 98)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1557)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 278)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 258)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 378)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 160)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 155)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 301)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 509)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 5645)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 217)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 296)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 288)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 40)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 5640)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 90)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 2589)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 441)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 400)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 156)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 297)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 448)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 127)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1547)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 30)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 304)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 63)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 353)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3598)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1568)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 409)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3608)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 510)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 3603)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 447)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 363)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 1537)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 6659)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 6658)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 212)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales', 214)
#
#
#     INSERT INTO [Prod-CASMaster].[dbo].[Logins2Roles] (UserId, RoleName, ModifiedBy, FKCaseId)
#     VALUES('Jenny.Luk', 'IT System Administrator', 'Oscar.Morales',